# %% [markdown]
# # Use this notbook for your 3 choices of APIs

# %%
import pandas as pd
import requests

# %%
fruits = requests.get('https://www.fruityvice.com//api/fruit/all').json()
fruits
# Out:
# [{'genus': 'Malus',
#   'name': 'Apple',
#   'id': 6,
#   'family': 'Rosaceae',
#   'order': 'Rosales',
#   'nutritions': {'carbohydrates': 11.4,
#    'protein': 0.3,
#    'fat': 0.4,
#    'calories': 52,
#    'sugar': 10.3}},
#  {'genus': 'Prunus',
#   'name': 'Apricot',
#   'id': 35,
#   'family': 'Rosaceae',
#   'order': 'Rosales',
#   'nutritions': {'carbohydrates': 3.9,
#    'protein': 0.5,
#    'fat': 0.1,
#    'calories': 15,
#    'sugar': 3.2}},
#  {'genus': 'Persea',
#   'name': 'Avocado',
#   'id': 84,
#   'family': 'Lauraceae',
#   'order': 'Laurales',
#   'nutritions': {'carbohydrates': 8.53,
#    'protein': 2,
#    'fat': 14.66,
#    'calories': 160,
#    'sugar': 0.66}},
#  {'genus': 'Musa',
#   'name': 'Banana',
#   'id': 1,
#   'family': 'Musaceae',
#   'order': 'Zingiberales',
#   'nutritions': {'carbohydrates': 22,
#    'protein': 1,
#    'fat': 0.2,
#    'calories': 96,
#    'sugar': 17.2}},
#  {'genus': 'Rubus',
#   'name': 'Blackberry',
#   'id': 64,
# ...

# %%
from pandas.io.json import json_normalize
flattened_data = json_normalize(fruits)
flattened_data
# Out:
# /var/folders/y5/7v3j89sd4ps24p3x50lkvwf80000gn/T/ipykernel_4410/1774411721.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data = json_normalize(fruits)
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae           Rosales
# 7      Theobroma     Chocolate  88        Malvaceae          Malvales
# 8      Vaccinium     Cranberry  87        Ericaceae          Ericales
# ...

# %%
#-----------------------------------------------------#

# %%
books = requests.get('http://openlibrary.org/search.json?author=tolkien')

# %%
results = books.json()

# %%
flattened_data = json_normalize(results['docs'])
# Out:
# /var/folders/y5/7v3j89sd4ps24p3x50lkvwf80000gn/T/ipykernel_4410/415777833.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattened_data = json_normalize(results['docs'])

# %%
flattened_data
# Out:
#                    key  type  \
# 0     /works/OL262758W  work
# 1      /works/OL27448W  work
# 2      /works/OL27479W  work
# 3      /works/OL27516W  work
# 4   /works/OL14933414W  work
# ..                 ...   ...
# 95  /works/OL25483632W  work
# 96  /works/OL21800645W  work
# 97  /works/OL21887224W  work
# 98   /works/OL8997777W  work
# 99   /works/OL8997780W  work
#
#                                                  seed  \
# 0   [/books/OL28345239M, /books/OL9228183M, /books...
# 1   [/books/OL9158246M, /books/OL9177076M, /books/...
# 2   [/books/OL27296256M, /books/OL31879906M, /book...
# 3   [/books/OL31905946M, /books/OL9924431M, /books...
# 4   [/books/OL8889789M, /books/OL22266040M, /books...
# ..                                                ...
# 95  [/books/OL34277064M, /books/OL34179319M, /work...
# 96  [/books/OL29693941M, /books/OL30819626M, /work...
# 97  [/books/OL29848936M, /works/OL21887224W, /auth...
# 98  [/books/OL9076654M, /works/OL8997777W, /author...
# ...

# %%
#--------------------------------------------------------#

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

import yfinance as yf

# %%
df_yahoo = yf.download(["AAPL"],
start='2020-09-15',
end='2022-01-10',
progress=False)

# %%
df_yahoo.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-09-15  118.330002  118.830002  113.610001  115.540001  113.972847
# 2020-09-16  115.230003  116.000000  112.040001  112.129997  110.609093
# 2020-09-17  109.720001  112.199997  108.709999  110.339996  108.843369
# 2020-09-18  110.400002  110.879997  106.089996  106.839996  105.390831
# 2020-09-21  104.540001  110.190002  103.099998  110.080002  108.586899
#
#                Volume
# Date
# 2020-09-15  184642000
# 2020-09-16  154679000
# 2020-09-17  178011000
# 2020-09-18  287104900
# 2020-09-21  195713800
